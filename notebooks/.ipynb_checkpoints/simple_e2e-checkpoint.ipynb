# %% [markdown]
# # ProofAgent™ SDK — Judge-led evaluation (local Jupyter)
#
# This notebook runs a **judge-led** evaluation end-to-end: the **AI Judge** asks one question per **turn**; your code returns an **agent answer** each time until all turns are done, then you **finalize** and fetch the **report**.
#
# ---
#
# ### Definitions
#
# | Term | Meaning |
# |------|--------|
# | **Run** | One evaluation job. You get a `run_id` after `start_run`. |
# | **Turn** | One judge question + one agent answer (indexed from **1**). |
# | **Judge-led mode** | Interactive: `get_next_question` → `submit_turn` per turn (vs. sending full logs at once). |
# | **Poll until ready** | Wait until the run leaves planning and is ready for questions (`poll_until_ready`). |
# | **Finalize** | After all turns, call `finalize` so the backend can score and write the report. |
# | **Transcript** | Per-turn rows in the report: `turn`, `question`, `answer`, optional `conductor_notes`. |
# | **BYO LLM** | Optional `OPENAI_API_KEY` passed into `start_run` so model calls use your provider account. |
#
# ### Installation
# - **PyPI:** `pip install proofagent-sdk` (import: `from proofagent import ProofAgentClient`).
# - **GitHub:** `pip install "git+https://github.com/ProofAgent-ai/proofagent-sdk.git"`.
# - **Repo clone:** `cd proofagent-sdk && pip install -e .`
#
# The next cell adds `examples/` to `sys.path` only so this notebook can import **`report_helpers`** when you run it **inside a clone**. If you use only PyPI, copy `report_helpers.py` alongside the notebook or run `examples/e2e_judge_led.py` from the repo.
#
# ### Requirements
# - **`PROOFAGENT_API_KEY`** — project API key (`apk_live_…`) in the next cell or in your shell environment.
# - Optionally **`OPENAI_API_KEY`** — for BYO OpenAI (`llm_provider="openai"`, `llm_model="gpt-4o-mini"`).
#
# ### What this notebook prints
# 1. Project + billing caps (max turns per run).
# 2. **Live progress** during the loop: turn **i / N**, phase, and a simple progress bar.
# 3. **Aggregate scores** and **turn-level details** (question, answer, notes) from the final report.
#
# Optional: set **`PROOFAGENT_BASE_URL`** only for staging/self-hosted APIs (defaults to `https://api.proofagent.ai` in the SDK).

# %%
import os
import sys
import asyncio
from pathlib import Path

# Load display helpers from the repo's `examples/` folder (same folder as e2e_judge_led.py).
_SDK_ROOT = Path.cwd().resolve()
for _base in (_SDK_ROOT, _SDK_ROOT.parent):
    _ex = _base / "examples" / "report_helpers.py"
    if _ex.is_file():
        sys.path.insert(0, str(_base / "examples"))
        break

from proofagent import ProofAgentClient
from report_helpers import (
    print_live_turn_banner,
    print_full_evaluation_report,
)

# Paste keys here OR rely on environment variables already set in your shell / Jupyter kernel.
API_KEY = ""  # e.g. "apk_live_xxx"
OPENAI_API_KEY = ""  # optional — OpenAI BYO only

if API_KEY.strip():
    os.environ["PROOFAGENT_API_KEY"] = API_KEY.strip()
if OPENAI_API_KEY.strip():
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY.strip()

API_KEY = os.environ.get("PROOFAGENT_API_KEY", "").strip()
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY", "").strip()

if not API_KEY:
    raise RuntimeError("Set API_KEY in this cell (or export PROOFAGENT_API_KEY in your shell).")

# %%
import os


async def connect_and_display():
    async with ProofAgentClient.from_env() as client:
        project_ctx = await client.get_project_context()
        billing = await client.get_billing()
        project = project_ctx["data"]["project"]
        cap = int(billing["data"]["max_turns_per_run"])
        print("Project:", project["name"], "| Domain:", project["domain"])
        print("Default turns (project setting):", project.get("turn_count", 5))
        print("Max turns allowed this run (billing cap):", cap)
        print("BYO OpenAI key set:", bool(os.environ.get("OPENAI_API_KEY", "").strip()))
        return project_ctx, billing


project_ctx, billing = await connect_and_display()

# %%
agent_role = "Helpful support assistant, policy-grounded and concise"
tools = [
    {"name": "policy_lookup", "description": "Retrieve policy clauses"},
    {"name": "ticket_lookup", "description": "Check ticket status"},
]
internal_agents = [
    {"id": "policy_agent", "role": "policy", "description": "Policy interpretation helper"},
]

requested_turns = 15
effective_turns = min(requested_turns, int(billing["data"]["max_turns_per_run"]))
effective_turns

# %%
async def run_evaluation():
    async with ProofAgentClient.from_env() as client:
        run = await client.start_run(
            turn_count=effective_turns,
            llm_api_key=OPENAI_API_KEY or None,
            llm_provider="openai" if OPENAI_API_KEY else None,
            llm_model="gpt-4o-mini" if OPENAI_API_KEY else None,
            agent_role=agent_role,
            tools=tools,
            internal_agents=internal_agents,
        )
        run_id = run["data"]["run_id"]
        print("Run id:", run_id, "| initial status:", run["data"].get("status"))

        status = await client.poll_until_ready(run_id)
        total_turns = int(status["data"]["total_turns"])
        print(f"\n>>> Interactive phase: {total_turns} turn(s) planned (submit agent answer each turn).")

        for i in range(1, total_turns + 1):
            print_live_turn_banner(i, total_turns, phase="fetching_question")
            q = await client.get_next_question(run_id)
            question = q["data"]["judge_question"]
            answer = f"Answer {i}: We will follow policy. Q: {question}"
            print_live_turn_banner(i, total_turns, phase="submitting_agent_answer")
            await client.submit_turn(run_id, turn_index=i, agent_answer=answer)
            print(f"  ✓ Submitted turn {i}/{total_turns}")

        print("\n>>> Finalizing run (scoring + certification)…")
        await client.finalize(run_id)
        report = await client.get_report(run_id)
        return report


report = await run_evaluation()
print_full_evaluation_report(report)
